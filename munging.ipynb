# %%
#Load Dependencies
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
#Load in Data
teams_df = pd.read_csv("Data/cfbstats-com-2013-1-5-20/team.csv")
player_df = pd.read_csv("Data/cfbstats-com-2013-1-5-20/player.csv")
stadium_df = pd.read_csv("Data/cfbstats-com-2013-1-5-20/stadium.csv")
conference_df = pd.read_csv("Data/cfbstats-com-2013-1-5-20/conference.csv")
game_df = pd.read_csv("Data/cfbstats-com-2013-1-5-20/game.csv")
game_attendance_df = pd.read_csv("Data/cfbstats-com-2013-1-5-20/game-statistics.csv")
pass_df = pd.read_csv("Data/cfbstats-com-2013-1-5-20/pass.csv")
rush_df = pd.read_csv("Data/cfbstats-com-2013-1-5-20/rush.csv")
game_statistics_df = pd.read_csv("Data/cfbstats-com-2013-1-5-20/team-game-statistics.csv")
# Out:
#    Player Code  Team Code  Last Name First Name Uniform Number Class Position  \
# 0      1022870          5  Alexander       Bill             21    SR       CB
# 1      1022862          5  Alexander  Broderick              2    SR       FB
# 2      1046129          5      Allen  Christian             49    FR       FB
# 3      1035204          5      Allen       Jeff             46    JR       DL
# 4      1030820          5     Bailey     Austin             40    SR       DL
#
#    Height  Weight        Home Town Home State Home Country  \
# 0    68.0   172.0          Whigham         GA           US
# 1    72.0   225.0        Covington         GA           US
# 2    72.0   249.0       Morgantown         WV           US
# 3    74.0   262.0       Morgantown         WV           US
# 4    71.0   262.0  West Friendship         MD           US
#
#                       Last School
# 0     George Washington Carver HS
# 1                     Eastside HS
# 2                   Morgantown HS
# ...

# %%
game_and_attendance = pd.merge(game_df, game_attendance_df , on='Game Code')

game_and_attendance
# Out:
#             Game Code        Date  Visit Team Code  Home Team Code  \
# 0       5012820130829  08/29/2013                5             128
# 1     102063020130829  08/29/2013              102             630
# 2     299004720130829  08/29/2013              299              47
# 3     305030620130829  08/29/2013              305             306
# 4     314071820130829  08/29/2013              314             718
# 5     355033120130829  08/29/2013              355             331
# 6     433073620130829  08/29/2013              433             736
# 7     457064820130829  08/29/2013              457             648
# 8     465042820130829  08/29/2013              465             428
# 9     587009620130829  08/29/2013              587              96
# 10    657027720130829  08/29/2013              657             277
# 11    667064620130829  08/29/2013              667             646
# 12    711016420130829  08/29/2013              711             164
# ...
